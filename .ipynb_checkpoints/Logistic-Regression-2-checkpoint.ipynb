# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import statsmodels.api as sm
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split
import seaborn as sns
from sklearn import metrics
from sklearn import datasets
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)


data = pd.read_csv('logistic_dataset.csv', header=0)
data = data.dropna()
print(data.shape)
print(list(data.columns))

headers = list(data.columns)
feature_headers = headers[0:-1]
target_header = headers[-1]

#data.head()

cat_vars=[]
for var in cat_vars:
    cat_list='var'+'_'+var
    cat_list = pd.get_dummies(data[var], prefix=var)
    data1=data.join(cat_list)
    data=data1

cat_vars=[]
data_vars=data.columns.values.tolist()
to_keep=[i for i in data_vars if i not in cat_vars]

data_final=data[to_keep]
data_final.columns.values

data_final_vars=data_final.columns.values.tolist()
y=['is_elite']
#y = column_or_1d(y, warn=True)
X=[i for i in data_final_vars if i not in y]

#data_vars=data.columns.values.tolist()


#y=data[feature_headers]
#X=data[target_header]

logreg = LogisticRegression()

rfe = RFE(logreg, 5)
rfe = rfe.fit(data_final[X], data_final[y] )
print(rfe.support_)
print(rfe.ranking_)


cols=['review_count', 'yelping_since_year', 'average_stars', 'funny', 'fans'] 
X=data_final[cols]
y=data_final['is_elite']

logit_model=sm.Logit(y,X)
result=logit_model.fit()
print(result.summary())


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
logreg = LogisticRegression()
logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))

cmatrix = confusion_matrix(y_test, y_pred)
print(cmatrix)

cm = pd.DataFrame(confusion_matrix(y_test, y_pred))
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True)
plt.show()
# Out:
# (422546, 8)
# ['review_count', 'yelping_since_year', 'average_stars', 'useful', 'funny', 'cool', 'fans', 'is_elite']
# [ True  True  True False  True False  True]
# [1 1 1 2 1 3 1]
# Optimization terminated successfully.
#          Current function value: 0.218537
#          Iterations 9
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               is_elite   No. Observations:               422546
# Model:                          Logit   Df Residuals:                   422541
# Method:                           MLE   Df Model:                            4
# Date:                Mon, 04 Dec 2017   Pseudo R-squ.:                  0.4351
# Time:                        20:50:38   Log-Likelihood:                -92342.
# converged:                       True   LL-Null:                   -1.6347e+05
#                                         LLR p-value:                     0.000
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# review_count           0.0190      0.000    168.801      0.000       0.019       0.019
# yelping_since_year    -0.0029   2.54e-05   -116.045      0.000      -0.003      -0.003
# average_stars          0.5856      0.013     46.303      0.000       0.561       0.610
# funny                 -0.0003   1.32e-05    -22.239      0.000      -0.000      -0.000
# fans                   0.0868      0.001     69.739      0.000       0.084       0.089
# ======================================================================================
# Accuracy of logistic regression classifier on test set: 0.92
# [[180430   3419]
#  [ 13563  13861]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-6e60a5b9c67b> in <module>()
#      81 print(confusion_matrix)
#      82
# ---> 83 cm = pd.DataFrame(confusion_matrix(y_test, y_pred))
#      84 plt.figure(figsize=(8, 6))
#      85 sns.heatmap(cm, annot=True)
#
# TypeError: 'numpy.ndarray' object is not callable
